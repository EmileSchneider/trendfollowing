# %%
from forecasts import * 
df = load_df()

# %%
symbol = 'ETHUSDT'
mom  = bollinger_momentum(df[symbol], df.index, 30, 2)
vals = mom.join(df[symbol].pct_change().shift(-1)).dropna()

for i in range(20, 70, 10):
    mom  = bollinger_momentum(df[symbol], df.index, 30, 2)
    vals = mom.join(df[symbol].pct_change().shift(-1)).dropna()
# Out:
# PearsonRResult(statistic=0.02866349470322075, pvalue=0.24469962796978997)
# <Axes: xlabel='opentime'>

# %%
vals[symbol].cumsum().plot()
# Out:
# <Axes: xlabel='opentime'>
